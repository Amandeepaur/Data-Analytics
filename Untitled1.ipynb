# %% [markdown]
# <a href="https://colab.research.google.com/github/Amandeepaur/Data-Analytics/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df1 = pd.read_csv("/Research Proposal/MELBOURNE_HOUSE_PRICES_LESS.csv")
df1.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode Total_sqft             Regionname  Propertycount  \
# 0  1/04/2017      3067        NaN  Northern Metropolitan           4019
# 1  1/04/2017      3067        NaN  Northern Metropolitan           4019
# 2  1/04/2017      3067       1440  Northern Metropolitan           4019
# 3  1/04/2017      3040       1521   Western Metropolitan           1543
# 4  1/04/2017      3042       1056   Western Metropolitan           3464
#
#    Distance                 CouncilArea
# 0       3.0          Yarra City Council
# ...

# %%
df1.shape
# Out:
# (63023, 14)

# %%
df1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Total_sqft', 'Regionname', 'Propertycount',
#        'Distance', 'CouncilArea'],
#       dtype='object')

# %%
df1['Postcode'].unique()
# Out:
# array([3067, 3040, 3042, 3021, 3206, 3020, 3078, 3018, 3028, 3025, 3143,
#        3032, 3147, 3195, 3049, 3034, 3103, 3104, 3153, 3193, 3081, 3204,
#        3165, 3130, 3196, 3155, 3128, 3019, 3186, 3187, 3047, 3056, 3057,
#        3055, 3105, 3083, 3125, 3151, 3124, 3126, 3053, 3054, 3163, 3023,
#        3197, 3201, 3145, 3161, 3162, 3148, 3192, 3756, 3168, 3169, 3068,
#        3058, 3066, 3064, 3977, 3136, 3175, 3340, 3037, 3089, 3172, 3108,
#        3109, 3111, 3084, 3002, 3185, 3095, 3184, 3802, 3076, 3041, 3060,
#        3156, 3065, 3011, 3131, 3199, 3200, 3043, 3146, 3150, 3046, 3088,
#        3059, 3188, 3122, 3135, 3190, 3029, 3166, 3079, 3038, 3033, 3031,
#        3101, 3102, 3173, 3012, 3180, 3337, 3075, 3140, 3085, 3144, 3048,
#        3000, 3194, 3754, 3082, 3132, 3094, 3039, 3189, 3138, 3149, 3170,
#        3805, 3015, 3174, 3051, 3070, 3167, 3810, 3052, 3044, 3090, 3030,
#        3207, 3181, 3072, 3073, 3121, 3431, 3134, 3178, 3191, 3179, 3198,
# ...

# %%
df1['Postcode'].value_counts()
# Out:
# Postcode
# 3073    1241
# 3064    1093
# 3150    1084
# 3121     904
# 3046     895
#         ...
# 3341       1
# 3159       1
# 3980       1
# 3091       1
# 3797       1
# Name: count, Length: 225, dtype: int64

# %%
df2 = df1.drop(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method'],axis='columns')
df2.shape
# Out:
# (63023, 8)

# %% [markdown]
# Data Cleaning: Handle NA Values

# %%
df2.isnull().sum()
# Out:
# SellerG              0
# Date                 0
# Postcode             0
# Total_sqft       36309
# Regionname           0
# Propertycount        0
# Distance             0
# CouncilArea          0
# dtype: int64

# %%
df2.shape
# Out:
# (63023, 8)

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# SellerG          0
# Date             0
# Postcode         0
# Total_sqft       0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# dtype: int64

# %%
df3.shape
# Out:
# (26714, 8)

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Add new feature(integer) for bhk (Bedrooms Hall Kitchen)

# %%
df3['bhk'] = df3['Postcode'].astype(str).apply(lambda x: int(x.split(' ')[0]) if ' ' in x else int(x))
df3.bhk.unique()
# Out:
# <ipython-input-20-981f801f453c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bhk'] = df3['Postcode'].astype(str).apply(lambda x: int(x.split(' ')[0]) if ' ' in x else int(x))
# array([3067, 3040, 3042, 3021, 3206, 3020, 3078, 3018, 3028, 3025, 3143,
#        3032, 3147, 3195, 3049, 3034, 3103, 3104, 3153, 3193, 3081, 3204,
#        3165, 3130, 3196, 3155, 3128, 3019, 3186, 3187, 3047, 3056, 3057,
#        3055, 3105, 3083, 3125, 3151, 3124, 3126, 3053, 3054, 3163, 3023,
#        3197, 3201, 3145, 3161, 3162, 3148, 3192, 3756, 3168, 3169, 3068,
#        3058, 3066, 3064, 3977, 3136, 3175, 3340, 3037, 3089, 3172, 3108,
#        3109, 3111, 3084, 3002, 3185, 3095, 3184, 3802, 3076, 3041, 3060,
# ...

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df3[~df3['Total_sqft'].apply(is_float)].head(10)
# Out:
#            SellerG       Date  Postcode      Total_sqft  \
# 30   hockingstuart  1/04/2017      3034     2100 - 2850
# 56        Woodards  1/04/2017      3165     3010 - 3410
# 81        Marshall  1/04/2017      3186     2957 - 3450
# 122             RT  1/04/2017      3124     3067 - 8156
# 137            Ray  1/04/2017      3163     1042 - 1105
# 165       Woodards  1/04/2017      3058     1145 - 1340
# 188          Raine  1/04/2017      3340     1015 - 1540
# 224            Kay  1/04/2017      3184     1520 - 1740
# 410      Fletchers  1/04/2017      3094  34.46Sq. Meter
# 549              U  1/04/2017      3198     1195 - 1440
#
#                      Regionname  Propertycount  Distance  \
# 30         Western Metropolitan           4502       9.5
# 56        Southern Metropolitan          10969      13.8
# 81        Southern Metropolitan          10579      10.5
# 122       Southern Metropolitan           8920       7.7
# 137       Southern Metropolitan           7822      10.1
# ...

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df4 = df3.copy()
df4.Total_sqft = df4.Total_sqft.apply(convert_sqft_to_num)
df4 = df4[df4.Total_sqft.notnull()]
df4.head(2)
# Out:
#   SellerG       Date  Postcode  Total_sqft             Regionname  \
# 2  Nelson  1/04/2017      3067      1440.0  Northern Metropolitan
# 3   Barry  1/04/2017      3040      1521.0   Western Metropolitan
#
#    Propertycount  Distance                 CouncilArea   bhk
# 2           4019       3.0          Yarra City Council  3067
# 3           1543       7.5  Moonee Valley City Council  3040

# %%
df4.loc[30]
# Out:
# SellerG                       hockingstuart
# Date                              1/04/2017
# Postcode                               3034
# Total_sqft                           2475.0
# Regionname             Western Metropolitan
# Propertycount                          4502
# Distance                                9.5
# CouncilArea      Moonee Valley City Council
# bhk                                    3034
# Name: 30, dtype: object

# %%
(2100+2850)/2
# Out:
# 2475.0

# %% [markdown]
# Feature Engineering
# Add new feature called price per square feet

# %%
df5.to_csv("/Research Proposal/MELBOURNE_HOUSE_PRICES_LESS.csv",index=False)

# %%
df4.Location = df4.Location.apply(lambda x: x.strip())
Location_stats = df4['Location'].value_counts(ascending=False)
print(Location_stats)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-ea4f8015dc28> in <cell line: 1>()
# ----> 1 df4.Location = df4.Location.apply(lambda x: x.strip())
#       2 Location_stats = df4['Location'].value_counts(ascending=False)
#       3 print(Location_stats)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Location'
